# %%
import numpy as np

import cv2

# %%
img = cv2.imread('G:\GitLab\Objectify\Final_Output_Single_Masks\istockphoto-478525372-612x612.png', 0)

np.unique(img)
# Out:
# array([0, 2], dtype=uint8)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize = (10,10))
plt.imshow(img, cmap='viridis')
plt.colorbar()
plt.axis("off")
plt.show()
